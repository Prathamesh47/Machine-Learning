# %%
import pandas as pd
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
import seaborn as sms

# %%
df=pd.read_csv('cities_r2.csv')
df.head(10)
# Out:
#   name_of_city  state_code      state_name  dist_code  population_total  \
# 0      Abohar            3          PUNJAB          9            145238
# 1    Achalpur           27     MAHARASHTRA          7            112293
# 2    Adilabad           28  ANDHRA PRADESH          1            117388
# 3   Adityapur           20       JHARKHAND         24            173988
# 4       Adoni           28  ANDHRA PRADESH         21            166537
# 5    Agartala           16         TRIPURA          1            399688
# 6        Agra            9   UTTAR PRADESH         15           1574542
# 7   Ahmadabad           24         GUJARAT          7           5570585
# 8  Ahmadnagar           27     MAHARASHTRA         26            350905
# 9      Aizawl           15         MIZORAM          3            291822
#
#    population_male  population_female  0-6_population_total  \
# 0            76840              68398                 15870
# ...

# %%
df.isnull().sum()
# Out:
# name_of_city                      0
# state_code                        0
# state_name                        0
# dist_code                         0
# population_total                  0
# population_male                   0
# population_female                 0
# 0-6_population_total              0
# 0-6_population_male               0
# 0-6_population_female             0
# literates_total                   0
# literates_male                    0
# literates_female                  0
# sex_ratio                         0
# child_sex_ratio                   0
# effective_literacy_rate_total     0
# effective_literacy_rate_male      0
# effective_literacy_rate_female    0
# location                          0
# total_graduates                   0
# male_graduates                    0
# female_graduates                  0
# dtype: int64

# %%
x=df[['total_graduates']]
print(x)
# Out:
#      total_graduates
# 0              16287
# 1               8863
# 2              10565
# 3              19225
# 4              11902
# ..               ...
# 488            30656
# 489           109613
# 490            19363
# 491            29803
# 492            13511
#
# [493 rows x 1 columns]

# %%
wcss=[]
for i in range(1,11):
    kmeans=KMeans(n_clusters=i, random_state=42)
    kmeans.fit(x)
    wcss.append(kmeans.inertia_)
plt.plot(range(1,11),wcss)
plt.xlabel('Number of clusters')
plt.ylabel("wcss")
plt.title('Knee curve')
plt.show()
# Out:
# C:\Users\prath\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:881: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(

# %%
kmeans=KMeans(n_clusters=3, random_state=42)
df['clusters']=kmeans.fit_predict(x)

# %%
print(df[['name_of_city','total_graduates','clusters']])
# Out:
#       name_of_city  total_graduates  clusters
# 0          Abohar             16287         0
# 1        Achalpur              8863         0
# 2        Adilabad             10565         0
# 3       Adityapur             19225         0
# 4           Adoni             11902         0
# ..             ...              ...       ...
# 488  Vizianagaram             30656         0
# 489      Warangal            109613         0
# 490        Wardha             19363         0
# 491   Yamunanagar             29803         0
# 492      Yavatmal             13511         0
#
# [493 rows x 3 columns]

# %%
sms.scatterplot(x='name_of_city',y='total_graduates',hue='clusters',data=df)
plt.xlabel('name of city')
plt.ylabel('total graduates')
plt.title('KMeans clustering')
plt.show()
